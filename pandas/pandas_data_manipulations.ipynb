# %%
import pandas as pd
import numpy as np

# %%
titanic_train = pd.read_csv("https://gist.githubusercontent.com/michhar/2dfd2de0d4f8727f873422c5d959fff5/raw/ff414a1bcfcba32481e4d4e8db578e55872a2ca1/titanic.csv",
                           sep='\t')

titanic_train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
titanic_train.head()     #head loads the 5 records of the data from upside of dataframe
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic_train.tail()            #head loads the 5 records of the data from bottom of dataframe
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 151          152         1       1  Pears, Mrs. Thomas (Edith Wearne)  female
# 152          153         0       3                   Meo, Mr. Alfonzo    male
# 153          154         0       3    van Billiard, Mr. Austin Blyler    male
# 154          155         0       3              Olsen, Mr. Ole Martin    male
# 155          156         0       1        Williams, Mr. Charles Duane    male
#
#       Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 151  22.0      1      0      113776  66.6000    C2        S
# 152  55.5      0      0  A.5. 11206   8.0500   NaN        S
# 153  40.5      0      2    A/5. 851  14.5000   NaN        S
# 154   NaN      0      0   Fa 265302   7.3125   NaN        S
# 155  51.0      0      1    PC 17597  61.3792   NaN        C

# %%
type(titanic_train["Name"])
# Out:
# pandas.core.series.Series

# %%
titanic_train["Name"]
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
# 5                                       Moran, Mr. James
# 6                                McCarthy, Mr. Timothy J
# 7                         Palsson, Master. Gosta Leonard
# 8      Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                    Nasser, Mrs. Nicholas (Adele Achem)
# 10                       Sandstrom, Miss. Marguerite Rut
# 11                              Bonnell, Miss. Elizabeth
# 12                        Saundercock, Mr. William Henry
# 13                           Andersson, Mr. Anders Johan
# 14                  Vestrom, Miss. Hulda Amanda Adolfina
# 15                      Hewlett, Mrs. (Mary D Kingcome)
# ...

# %%
titanic_train[["Name", "Sex", "Age"]].head()
# Out:
#                                                 Name     Sex   Age
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0

# %%
titanic_train.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
titanic_train.dtypes == "object"
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
titanic_train.dtypes[titanic_train.dtypes == "object"]         #Filtering the data by object type
# Out:
# Name        object
# Sex         object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %%
titanic_train.dtypes[titanic_train.dtypes == "object"].index
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
a = titanic_train.dtypes[titanic_train.dtypes == "object"].index
titanic_train[a]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# 5                                     Moran, Mr. James    male
# 6                              McCarthy, Mr. Timothy J    male
# 7                       Palsson, Master. Gosta Leonard    male
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female
# 10                     Sandstrom, Miss. Marguerite Rut  female
# 11                            Bonnell, Miss. Elizabeth  female
# 12                      Saundercock, Mr. William Henry    male
# 13                         Andersson, Mr. Anders Johan    male
# ...

# %%
b = titanic_train.dtypes[titanic_train.dtypes == "int64"].index         #Filtering the data by int64 type
titanic_train[b]
# Out:
#      PassengerId  Survived  Pclass  SibSp  Parch
# 0              1         0       3      1      0
# 1              2         1       1      1      0
# 2              3         1       3      0      0
# 3              4         1       1      1      0
# 4              5         0       3      0      0
# 5              6         0       3      0      0
# 6              7         0       1      0      0
# 7              8         0       3      3      1
# 8              9         1       3      0      2
# 9             10         1       2      1      0
# 10            11         1       3      1      1
# 11            12         1       1      0      0
# 12            13         0       3      0      0
# 13            14         0       3      1      5
# 14            15         0       3      0      0
# 15            16         1       2      0      0
# 16            17         0       3      4      1
# 17            18         1       2      0      0
# ...

# %%
titanic_train[a].describe()            #categriacal data description (only on object type fields) and 
                                       #we can find how many NaN values in fields
# Out:
#                                Name   Sex   Ticket Cabin Embarked
# count                           156   156      156    31      155
# unique                          156     2      145    28        3
# top     Andersson, Mr. Anders Johan  male  CA 2144   D26        S
# freq                              1   100        2     2      110

# %%
titanic_train.describe()            #int and float data description (on hole dataframe)
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   156.000000  156.000000  156.000000  126.000000  156.000000
# mean     78.500000    0.346154    2.423077   28.141508    0.615385
# std      45.177428    0.477275    0.795459   14.613880    1.056235
# min       1.000000    0.000000    1.000000    0.830000    0.000000
# 25%      39.750000    0.000000    2.000000   19.000000    0.000000
# 50%      78.500000    0.000000    3.000000   26.000000    0.000000
# 75%     117.250000    1.000000    3.000000   35.000000    1.000000
# max     156.000000    1.000000    3.000000   71.000000    5.000000
#
#             Parch        Fare
# count  156.000000  156.000000
# mean     0.397436   28.109587
# std      0.870146   39.401047
# min      0.000000    6.750000
# 25%      0.000000    8.003150
# 50%      0.000000   14.454200
# 75%      0.000000   30.371850
# max      5.000000  263.000000

# %%
sorted(titanic_train["Name"])    #column sort
# Out:
# ['Ahlin, Mrs. Johan (Johanna Persdotter Larsson)',
#  'Allen, Mr. William Henry',
#  'Andersson, Miss. Ellis Anna Maria',
#  'Andersson, Miss. Erna Alexandra',
#  'Andersson, Mr. Anders Johan',
#  'Andersson, Mr. August Edvard ("Wennerstrom")',
#  'Andreasson, Mr. Paul Edvin',
#  'Andrew, Mr. Edgardo Samuel',
#  'Arnold-Franchi, Mrs. Josef (Josefine Franchi)',
#  'Asplund, Mrs. Carl Oscar (Selma Augusta Emilia Johansson)',
#  'Attalah, Miss. Malake',
#  'Backstrom, Mrs. Karl Alfred (Maria Mathilda Gustafsson)',
#  'Barton, Mr. David John',
#  'Bateman, Rev. Robert James',
#  'Baxter, Mr. Quigg Edmond',
#  'Beesley, Mr. Lawrence',
#  'Bing, Mr. Lee',
#  'Bonnell, Miss. Elizabeth',
#  'Boulos, Mrs. Joseph (Sultana)',
#  'Braund, Mr. Owen Harris',
#  'Burke, Mr. Jeremiah',
#  'Byles, Rev. Thomas Roussel Davids',
#  'Caldwell, Master. Alden Gates',
#  'Cann, Mr. Ernest Charles',
#  'Carrau, Mr. Francisco M',
#  'Celotti, Mr. Francesco',
#  'Chaffee, Mr. Herbert Fuller',
# ...

# %%
sorted(titanic_train["Name"])[5:10:2]
# Out:
# ['Andersson, Mr. August Edvard ("Wennerstrom")',
#  'Andrew, Mr. Edgardo Samuel',
#  'Asplund, Mrs. Carl Oscar (Selma Augusta Emilia Johansson)']

# %%
titanic_train["Name"].describe()
# Out:
# count                             156
# unique                            156
# top       Andersson, Mr. Anders Johan
# freq                                1
# Name: Name, dtype: object

# %%
titanic_train[["Ticket"]][4:9]                  #[["Ticket"]] --> Dataframe       ["Ticket"]  --> Series
# Out:
#    Ticket
# 4  373450
# 5  330877
# 6   17463
# 7  349909
# 8  347742

# %%
titanic_train["Ticket"][4:9]           #["Ticket"]  --> Series
# Out:
# 4    373450
# 5    330877
# 6     17463
# 7    349909
# 8    347742
# Name: Ticket, dtype: object

# %%
titanic_train.columns        #For all the columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
titanic_train["Test"]=0            #Creating new column withall the values as 0
titanic_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Test
# 0      0         A/5 21171   7.2500   NaN        S     0
# 1      0          PC 17599  71.2833   C85        C     0
# 2      0  STON/O2. 3101282   7.9250   NaN        S     0
# 3      0            113803  53.1000  C123        S     0
# ...

# %% [markdown]
# # Categorical  *Important*  --> conversion neumerical to categorical

# %%
new_df = pd.Categorical(titanic_train["Pclass"])      # finding the neumerical to change as Categorical
new_df
# Out:
# [3, 1, 3, 1, 3, ..., 1, 3, 3, 3, 1]
# Length: 156
# Categories (3, int64): [1, 2, 3]

# %%
new_df1 = new_df.rename_categories(["c1", "c2", "c3"])        # Changing the neumerical to Categorical
new_df1                                                       # Here values changed as 1-c1, 2-c2, 3-c3
# Out:
# [c3, c1, c3, c1, c3, ..., c1, c3, c3, c3, c1]
# Length: 156
# Categories (3, object): [c1, c2, c3]

# %%
titanic_train["Cabin"].unique()                     # Check unique Cabins
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2'], dtype=object)

# %%
char_cabin = titanic_train["Cabin"].astype(str)               #converting whole column into string
char_cabin
# Out:
# 0              nan
# 1              C85
# 2              nan
# 3             C123
# 4              nan
# 5              nan
# 6              E46
# 7              nan
# 8              nan
# 9              nan
# 10              G6
# 11            C103
# 12             nan
# 13             nan
# 14             nan
# 15             nan
# 16             nan
# 17             nan
# 18             nan
# 19             nan
# 20             nan
# 21             D56
# 22             nan
# 23              A6
# 24             nan
# 25             nan
# 26             nan
# 27     C23 C25 C27
# 28             nan
# 29             nan
#           ...
# 126            nan
# 127            nan
# 128          F E69
# 129            nan
# 130            nan
# 131            nan
# 132            nan
# 133            nan
# 134            nan
# 135            nan
# 136            D47
# 137           C123
# 138            nan
# 139            B86
# 140            nan
# 141            nan
# ...

# %%
new_cabin = [cabin[0] for cabin in char_cabin]                #Extracting first letter from cabin names
new_cabin
# Out:
# ['n',
#  'C',
#  'n',
#  'C',
#  'n',
#  'n',
#  'E',
#  'n',
#  'n',
#  'n',
#  'G',
#  'C',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'D',
#  'n',
#  'A',
#  'n',
#  'n',
#  'n',
#  'C',
#  'n',
#  'n',
#  'n',
#  'B',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'D',
#  'n',
#  'B',
#  'C',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'B',
#  'C',
#  'n',
#  'n',
#  'n',
#  'F',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'F',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'C',
#  'n',
#  'n',
#  'n',
#  'E',
#  'n',
#  'n',
#  'n',
#  'A',
#  'D',
#  'n',
#  'n',
#  'n',
#  'n',
#  'D',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'C',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'B',
#  'n',
#  'n',
#  'n',
#  'n',
#  'E',
#  'D',
# ...

# %%
new_cabin_cat = pd.Categorical(new_cabin)       #Categorical 
new_cabin_cat
# Out:
# [n, C, n, C, n, ..., C, n, n, n, n]
# Length: 156
# Categories (8, object): [A, B, C, D, E, F, G, n]

# %%
titanic_train["Age"].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5       True
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17      True
# 18     False
# 19      True
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26      True
# 27     False
# 28      True
# 29      True
#        ...
# 126     True
# 127    False
# 128     True
# 129    False
# 130    False
# 131    False
# 132    False
# 133    False
# 134    False
# 135    False
# 136    False
# 137    False
# 138    False
# 139    False
# 140     True
# 141    False
# 142    False
# 143    False
# 144    False
# 145    False
# 146    False
# 147    False
# 148    False
# 149    False
# 150    False
# 151    False
# 152    False
# 153    False
# 154     True
# 155    False
# Name: Age, Length: 156, dtype: bool

# %%
import numpy as np
missing = np.where(titanic_train["Age"].isnull()==True)       #Indexes of Null values in Age field
missing
# Out:
# (array([  5,  17,  19,  26,  28,  29,  31,  32,  36,  42,  45,  46,  47,
#          48,  55,  64,  65,  76,  77,  82,  87,  95, 101, 107, 109, 121,
#         126, 128, 140, 154], dtype=int32),)

# %%
np.where(titanic_train["Fare"] == max(titanic_train["Fare"]))     #Give the indexes of Maximum values
# Out:
# (array([27, 88], dtype=int32),)

# %% [markdown]
# # Row operations

# %%
titanic_train.iloc[np.where(titanic_train["Fare"] == max(titanic_train["Fare"]))]           #Fetching row from particular index
# Out:
#     PassengerId  Survived  Pclass                            Name     Sex  \
# 27           28         0       1  Fortune, Mr. Charles Alexander    male
# 88           89         1       1      Fortune, Miss. Mabel Helen  female
#
#      Age  SibSp  Parch Ticket   Fare        Cabin Embarked  Test
# 27  19.0      3      2  19950  263.0  C23 C25 C27        S     0
# 88  23.0      3      2  19950  263.0  C23 C25 C27        S     0

# %%
titanic_train["Family"] = titanic_train["SibSp"] + titanic_train["Parch"]    #Concatinating two columns
titanic_train["Family"]
# Out:
# 0      1
# 1      1
# 2      0
# 3      1
# 4      0
# 5      0
# 6      0
# 7      4
# 8      2
# 9      1
# 10     2
# 11     0
# 12     0
# 13     6
# 14     0
# 15     0
# 16     5
# 17     0
# 18     1
# 19     0
# 20     0
# 21     0
# 22     0
# 23     0
# 24     4
# 25     6
# 26     0
# 27     5
# 28     0
# 29     0
#       ..
# 126    0
# 127    0
# 128    2
# 129    0
# 130    0
# 131    0
# 132    1
# 133    1
# 134    0
# 135    0
# 136    2
# 137    1
# 138    0
# 139    0
# 140    2
# 141    0
# 142    1
# 143    0
# 144    0
# 145    2
# 146    0
# 147    4
# 148    2
# 149    0
# 150    0
# 151    1
# 152    0
# 153    2
# 154    0
# 155    1
# Name: Family, Length: 156, dtype: int64

# %%
most_family = np.where(titanic_train["Family"] == max(titanic_train["Family"]))
most_family
# Out:
# (array([59, 71], dtype=int32),)

# %%
titanic_train.iloc[most_family]
# Out:
#     PassengerId  Survived  Pclass                                Name     Sex  \
# 59           60         0       3  Goodwin, Master. William Frederick    male
# 71           72         0       3          Goodwin, Miss. Lillian Amy  female
#
#      Age  SibSp  Parch   Ticket  Fare Cabin Embarked  Test  Family
# 59  11.0      5      2  CA 2144  46.9   NaN        S     0       7
# 71  16.0      5      2  CA 2144  46.9   NaN        S     0       7

# %% [markdown]
# # Index Lables

# %%
import numpy as np
import pandas as pd

lables=["a", "b", "c"]
my_data = [10, 20, 30]

arr = np.array(my_data)
# arr
d = {"a":10, "b":20, "c":30}

pd.Series(my_data)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(my_data, index=lables)             #Adding custom lables to index
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(arr)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int32

# %%
ser1 = pd.Series([1,2,3,4], ["CA", "OR", "CO", "CA"])
ser2 = pd.Series([1,2,5,4], ["CA", "NV", "AZ", "OR"])
ser3 = ser1+ser2                                          #Addition between Series
ser3
# Out:
# AZ    NaN
# CA    2.0
# CA    5.0
# CO    NaN
# NV    NaN
# OR    6.0
# dtype: float64

# %%
from numpy.random import randn as rn
matrix_data = rn(5,4)                          #Creates random matrix
matrix_data
# Out:
# array([[-0.54719569, -1.86962393,  0.30603746, -2.48104547],
#        [ 0.21751906, -0.06495515,  0.38074031, -0.03390874],
#        [ 0.39032718, -0.60190669, -0.18012151, -0.41246015],
#        [-0.38121341, -0.67390621, -0.15999436,  0.96637433],
#        [-1.56686511,  0.66584125, -1.20488067,  0.15855432]])

# %%
row_lables = ["A", "B", "C", "D", "E"]
column_headings = ["W", "X", "Y", "Z"]
df = pd.DataFrame(matrix_data, row_lables, column_headings)
df
# Out:
#           W         X         Y         Z
# A -0.547196 -1.869624  0.306037 -2.481045
# B  0.217519 -0.064955  0.380740 -0.033909
# C  0.390327 -0.601907 -0.180122 -0.412460
# D -0.381213 -0.673906 -0.159994  0.966374
# E -1.566865  0.665841 -1.204881  0.158554

# %%
 df.iloc[2]              #Row data from default index (iloc works with default index)
                          #--> iloc, ix, loc can use to get the Row data
# Out:
# W    0.390327
# X   -0.601907
# Y   -0.180122
# Z   -0.412460
# Name: C, dtype: float64

# %%
df['Y']                #Column Data
# Out:
# A    0.306037
# B    0.380740
# C   -0.180122
# D   -0.159994
# E   -1.204881
# Name: Y, dtype: float64

# %%
df.loc["B"]                 #Row data with loc(loc can work with custom index)
# Out:
# W    0.217519
# X   -0.064955
# Y    0.380740
# Z   -0.033909
# Name: B, dtype: float64

# %%
df["New"] = df["X"] + df["Y"]
df["New (Sum of X and Z)"] = df["X"] + df["Z"]                 #Concatinating the two DataFrames
print(df)
# Out:
#           W         X         Y         Z       New  New (Sum of X and Z)
# A -0.547196 -1.869624  0.306037 -2.481045 -1.563586             -4.350669
# B  0.217519 -0.064955  0.380740 -0.033909  0.315785             -0.098864
# C  0.390327 -0.601907 -0.180122 -0.412460 -0.782028             -1.014367
# D -0.381213 -0.673906 -0.159994  0.966374 -0.833901              0.292468
# E -1.566865  0.665841 -1.204881  0.158554 -0.539039              0.824396

# %%
df.drop("A")                        #Dropping Row with default axis as 0
# Out:
#           W         X         Y         Z       New  New (Sum of X and Z)
# B  0.217519 -0.064955  0.380740 -0.033909  0.315785             -0.098864
# C  0.390327 -0.601907 -0.180122 -0.412460 -0.782028             -1.014367
# D -0.381213 -0.673906 -0.159994  0.966374 -0.833901              0.292468
# E -1.566865  0.665841 -1.204881  0.158554 -0.539039              0.824396

# %%
df.drop("W", axis=1)              #Dropping Column with axis as 1
# Out:
#           X         Y         Z       New  New (Sum of X and Z)
# A -1.869624  0.306037 -2.481045 -1.563586             -4.350669
# B -0.064955  0.380740 -0.033909  0.315785             -0.098864
# C -0.601907 -0.180122 -0.412460 -0.782028             -1.014367
# D -0.673906 -0.159994  0.966374 -0.833901              0.292468
# E  0.665841 -1.204881  0.158554 -0.539039              0.824396

# %%
df            #Original dataframe
# Out:
#           W         X         Y         Z       New  New (Sum of X and Z)
# A -0.547196 -1.869624  0.306037 -2.481045 -1.563586             -4.350669
# B  0.217519 -0.064955  0.380740 -0.033909  0.315785             -0.098864
# C  0.390327 -0.601907 -0.180122 -0.412460 -0.782028             -1.014367
# D -0.381213 -0.673906 -0.159994  0.966374 -0.833901              0.292468
# E -1.566865  0.665841 -1.204881  0.158554 -0.539039              0.824396

# %%
df.drop("X", axis=1, inplace=True)         #Deleting column parmenently from dataframe

# %%
df
# Out:
#           W         Y         Z       New  New (Sum of X and Z)
# A -0.547196  0.306037 -2.481045 -1.563586             -4.350669
# B  0.217519  0.380740 -0.033909  0.315785             -0.098864
# C  0.390327 -0.180122 -0.412460 -0.782028             -1.014367
# D -0.381213 -0.159994  0.966374 -0.833901              0.292468
# E -1.566865 -1.204881  0.158554 -0.539039              0.824396

# %% [markdown]
# # Multiple Rows

# %%
df.iloc[[0, 1]]                  #For multiple rows with original index
# Out:
#           W         Y         Z       New  New (Sum of X and Z)
# A -0.547196  0.306037 -2.481045 -1.563586             -4.350669
# B  0.217519  0.380740 -0.033909  0.315785             -0.098864

# %%
df.loc[["A", "B"]]                #For multiple rows with custom index
# Out:
#           W         Y         Z       New  New (Sum of X and Z)
# A -0.547196  0.306037 -2.481045 -1.563586             -4.350669
# B  0.217519  0.380740 -0.033909  0.315785             -0.098864

# %%
print (df.loc[["B","C"],["Y","W"]])             #Intersection of B and C, Y and W
# Out:
#           Y         W
# B  0.380740  0.217519
# C -0.180122  0.390327

# %%
df
# Out:
#           W         Y         Z       New  New (Sum of X and Z)
# A -0.547196  0.306037 -2.481045 -1.563586             -4.350669
# B  0.217519  0.380740 -0.033909  0.315785             -0.098864
# C  0.390327 -0.180122 -0.412460 -0.782028             -1.014367
# D -0.381213 -0.159994  0.966374 -0.833901              0.292468
# E -1.566865 -1.204881  0.158554 -0.539039              0.824396

# %%
df.iloc[[1,2,3],[0,1,2]]               #Intersection
# Out:
#           W         Y         Z
# B  0.217519  0.380740 -0.033909
# C  0.390327 -0.180122 -0.412460
# D -0.381213 -0.159994  0.966374

# %%
df.iloc[[1],[2]]
# Out:
#           Z
# B -0.033909

# %%
l = [1,2,3,4,5,6]
l[4:1:-1]
# Out:
# [5, 4, 3]

# %%
df.loc[["A"], ["W"]]                       #For individual value of custom indexes
# Out:
#           W
# A -0.547196

# %%
df.loc[["D"], ["Z"]]
# Out:
#           Z
# D  0.966374

# %%
df.iloc[[3],[2]]                      #For individual value of original indexes
# Out:
#           Z
# D  0.966374

# %%
df
# Out:
#           W         Y         Z       New  New (Sum of X and Z)
# A -0.547196  0.306037 -2.481045 -1.563586             -4.350669
# B  0.217519  0.380740 -0.033909  0.315785             -0.098864
# C  0.390327 -0.180122 -0.412460 -0.782028             -1.014367
# D -0.381213 -0.159994  0.966374 -0.833901              0.292468
# E -1.566865 -1.204881  0.158554 -0.539039              0.824396

# %%
df.iloc[0,2]
# Out:
# -2.4810454722262265

# %%
df.iloc[1,2]
# Out:
# -0.033908743673213164

# %%
df.iloc[:,[2]]
# Out:
#           Z
# A -2.481045
# B -0.033909
# C -0.412460
# D  0.966374
# E  0.158554

# %%
print(df>0)
# Out:
#        W      Y      Z    New  New (Sum of X and Z)
# A  False   True  False  False                 False
# B   True   True  False   True                 False
# C   True  False  False  False                 False
# D  False  False   True  False                  True
# E  False  False   True  False                  True

# %%
print(df.loc[["A","B","C"]]>0)
# Out:
#        W      Y      Z    New  New (Sum of X and Z)
# A  False   True  False  False                 False
# B   True   True  False   True                 False
# C   True  False  False  False                 False

# %%
print(df[df>0])                         # <0 values are inserting as NaN
# Out:
#           W         Y         Z       New  New (Sum of X and Z)
# A       NaN  0.306037       NaN       NaN                   NaN
# B  0.217519  0.380740       NaN  0.315785                   NaN
# C  0.390327       NaN       NaN       NaN                   NaN
# D       NaN       NaN  0.966374       NaN              0.292468
# E       NaN       NaN  0.158554       NaN              0.824396

# %%
df.iloc[0,0] = 100                        #Inserting a value in particular cell

# %%
df
# Out:
#             W         Y         Z       New  New (Sum of X and Z)
# A  100.000000  0.306037 -2.481045 -1.563586             -4.350669
# B    0.217519  0.380740 -0.033909  0.315785             -0.098864
# C    0.390327 -0.180122 -0.412460 -0.782028             -1.014367
# D   -0.381213 -0.159994  0.966374 -0.833901              0.292468
# E   -1.566865 -1.204881  0.158554 -0.539039              0.824396

# %%
import pandas as pd
import numpy as np

matrix_data = np.matrix('22,45,78;65,89,54;78,45,96;23,41,65;160,14,56')
row_lables = ["A", "B", "C", "D", "E"]
column_headings = ["Age", "Height", "Weight"]
matrix_data
# Out:
# matrix([[ 22,  45,  78],
#         [ 65,  89,  54],
#         [ 78,  45,  96],
#         [ 23,  41,  65],
#         [160,  14,  56]])

# %%
df = pd.DataFrame(matrix_data, index=row_lables, columns=column_headings)
df
# Out:
#    Age  Height  Weight
# A   22      45      78
# B   65      89      54
# C   78      45      96
# D   23      41      65
# E  160      14      56

# %%
print(df["Weight"]>65)
# Out:
# A     True
# B    False
# C     True
# D    False
# E    False
# Name: Weight, dtype: bool

# %%
df1 = df[df["Weight"]>65]
df1
# Out:
#    Age  Height  Weight
# A   22      45      78
# C   78      45      96

# %%
df1.iloc[0, 1]
# Out:
# 45

# %%
df
# Out:
#    Age  Height  Weight
# A   22      45      78
# B   65      89      54
# C   78      45      96
# D   23      41      65
# E  160      14      56

# %%
df.reset_index(inplace=True, drop=True)           #Resetting the index and saving parmenently and droping the custom indexing with drop parameter

# %%
df
# Out:
#    Age  Height  Weight
# 0   22      45      78
# 1   65      89      54
# 2   78      45      96
# 3   23      41      65
# 4  160      14      56

# %%
df["professsion"] = "Student Teacher Engineer Doctor Nurse".split()
df
# Out:
#    Age  Height  Weight professsion
# 0   22      45      78     Student
# 1   65      89      54     Teacher
# 2   78      45      96    Engineer
# 3   23      41      65      Doctor
# 4  160      14      56       Nurse

# %% [markdown]
# # Creating the DataFrame with multi Index

# %%
hier_index = list(zip(["G1", "G1", "G1", "G2", "G2", "G2"], [1,2,3, 1,2,3]))
hier_index = pd.MultiIndex.from_tuples(hier_index)
hier_index
# Out:
# MultiIndex(levels=[['G1', 'G2'], [1, 2, 3]],
#            labels=[[0, 0, 0, 1, 1, 1], [0, 1, 2, 0, 1, 2]])

# %%
df2 = pd.DataFrame(data=np.round(rn(6,3)), index=hier_index, columns=["A", "B", "C"])
df2
# Out:
#         A    B    C
# G1 1  0.0  0.0 -1.0
#    2  2.0 -1.0  0.0
#    3  1.0 -0.0 -0.0
# G2 1  1.0 -0.0  1.0
#    2 -0.0 -3.0  0.0
#    3  0.0 -1.0  1.0

# %%
df3 = df2.loc['G1']              #G1 in multi index
df3
# Out:
#      A    B    C
# 1  0.0  0.0 -1.0
# 2  2.0 -1.0  0.0
# 3  1.0 -0.0 -0.0

# %%
df3.loc[1]                     #loc #loc and iloc both will work inside of multi indexing
# Out:
# A    0.0
# B    0.0
# C   -1.0
# Name: 1, dtype: float64

# %%
df3.iloc[0]                   #iloc #iloc extracting based on integer
# Out:
# A    0.0
# B    0.0
# C   -1.0
# Name: 1, dtype: float64

# %% [markdown]
# # Cross section

# %%
df2.xs('G1')
# Out:
#      A    B    C
# 1  0.0  0.0 -1.0
# 2  2.0 -1.0  0.0
# 3  1.0 -0.0 -0.0

# %%
booldf1 = df["Height"]>45
booldf2 = df["Weight"]>65
print ([booldf1 & booldf2])
# Out:
# [0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool]
